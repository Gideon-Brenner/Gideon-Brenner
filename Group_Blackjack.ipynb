# %% [markdown]
# # Blackjack
# In this project you will be coding a simple game of blackjack.
#
# Here is a helpful video for learning how to play: https://youtu.be/-9YGKFdP6sY
# ![blackjack.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Important Concepts
#
# **Ace**: Although in traditional blackjack you can choose if an ace counts as 1 or 11, we will count it as 1 to make things less complex
#
# **Bust**: a player busts if their total card values added together exceeds 21
#
# **Blackjack**: a blackjack occurs when a player gets exactly 21. This is an automatic win
#
# **Face Cards**: Ace, Jack, Queen, King

# %% [markdown]
# # Game Structure
# A general description of the game structure is given below; specifics instructions for each member of your team are listed later in the notebook.
#
# 1. When the game firsts begin, we will start the player with 10 dollars to "bet" with.
#
# 2. At the beginning of each round the user will be asked if they would like to play or quit. If they choose to quit, the game ends and you can see step 8. If they select to play, make sure they have more than 0 dollars. If they don't, end the game and go to step 8. If they have money to play, proceed to ask them how much they would like to bet.
# 3. Make sure that the user's bet is within their budget. If they are betting more money than they have, continue prompting them for bets until they provide an amount within budget.
#
# 3. The dealer will then randomly give the player and themselves 2 cards. You will implement this in the function stub, `deal`, below.
#
# 4. Now it's the player's turn! The player will continuously be asked to "hit" or "stay" until they select "stay". Each time they are prompted, print out their hand for them so they can see their cards. If they select "hit", you will add a random card to their hand. If they decide to hit and go over 21, they busted and the dealer has won the round.  You will implement this in the function stub, `players_turn`, below.
#
# 5. Once the player has decided to stay, it is the dealer's turn! Have the dealer continue adding cards to their hand until their total is greater than or equal to 17. They may already be greater than or equal to 17 from their two original cards. Print out the dealer's hand each time they add a card. You will implement this in the function stub, `dealers_turn`, below.
#
# 6. Now figure out who won by calling the function you will implement. Whoever is closer to 21 wins. If both players busted, the dealer wins. If it is a tie, the player wins. PYou will implement this in the function stub, `who_won`, below. rint a message about the results, add or subtract from the player's money accordingly if they win or lose, and return to step 2 for a new round.
#
# 7. When the game is over, display a message telling the user how much money they ended with.

# %% [markdown]
# # Demo
# Here is a [video demo](https://youtu.be/6XphwHsszTk) of the game. It does NOT have to look exactly the same as the version seen here. You may want to print out more or less than what this version shows. However, note that the more you print, the easier things will be to debug!

# %% [markdown]
# # Using the Random Library
# The random library can generate random numbers for us. To use it you import random which is provided for you. The choice function will pick a random item from the list. Here is an example of it being used below.
#
#
# ```
# import random
#
# x = ["list", "of", "random", "things]
# item = random.choice(x)
# ```

# %% [markdown]
# #Tips
# You may find it hard to deal with the face cards (ace, jack, queen, king) when taking sums. Decide how you want to handle these with your group. Consider making a dictionary. If not a dictionary, have conditional statements.
#
#
# You will likely find yourself in a lot of situations where you don't know how long a loop should repeat. Think about what type of loop is compatible with this and how to end it when neccessary.

# %% [markdown]
# #Run this block
# Here is a list of all the cards in the deck - run this code before you get started.

# %%
deck = ["Ace", "2", "3", "4", "5", "6", "7", "8", "9", "10", "Jack", "Queen", "King"]
deck_dict = {"Ace" : 4, "2": 4, "3" : 4, "4" : 4, "5" : 4, "6" : 4, "7" : 4, "8" : 4, "9" : 4, "Jack" : 4, "Queen" : 4, "King" : 4
             }

# %% [markdown]
# ## Realistic drawing
#
# If your group has a fourth teammate, Teammate #4 should implement this extension! The extension involves ensuring that the cards drawn from the deck are realistic (for instance, nobody's hand can really have six ones!). One way to implement it is listed below, but you may choose another method with no penalty.
#
# * You will create a function `draw_card` that takes no inputs and returns a card from the deck.
# * Instead of using the `deck` list, create a `deck` dictionary that initially stores the count `4` for each card. The keys represent the card number, and the values represent how many cards of that number are available.
# * In your function, create a `currently_available` list by looping through cards in your dictionary; you should add each card $n$ times, where $n$ is the value stored in the dictionary.
# * Randomly choose two cards from `currently_available` to return
# * Before returning, update `deck` such that the count for those cards goes down by one.
#
# You will create one more function called `reset_deck`. You must add a call to this function at the start of each round in you teammate's driver code. The function should do the following
# * Loop through all of the keys in `deck`
# * Set the values to 4
#
# NOTE: remember that when drawing cards from a shuffled deck, you will be more likely to draw a card that appears more times in that deck. Ensure that your algorithm accounts for this (the steps listed above do).

# %%
import random

def draw_card():
  currently_available_list = []
# making a list for all the available cards
  for card in deck_dict:
    for x in range (0 , deck_dict[card]):
# looking at the values in the dictionary
      currently_available_list.append(card)
  random_cards = []

  drawn_card = random.choice(currently_available_list)
# getting a random card from the deck
  deck_dict[drawn_card] = deck_dict[card] - 1
# subtracting 1 from the deck each time a card gets drawn
  return drawn_card

def reset_deck():
  for card in deck_dict:
    deck_dict[card] = 4

# %% [markdown]
# ## Dealing and Win Conditions
# Teammate #1 will work on three functions: `deal`, `sum_of_hand`, and `who_won`
#
# ### `deal`
# *  randomly select two cards from the deck
#    * If you are on a four member team, use your teammate's `draw_card` function
#    * If you are on a three member of team, pick a random card from the `deck` list using the `random` library
# *  this function takes no input, and returns a list of cards
#
# ### `sum_of_hand`
# * compute the score for a hand, which is a list of cards
# * ensure that you properly score face value cards
#
# ### `who_won`
# * This function takes in two integers, the final total of the player and dealer's hands.
# * A total of 0 for either player would indicate they busted.
# * If both busted, the dealer wins. If it is a tie the player wins.
# * Return `True` if the player won, `False` if the dealer won.
#
# The code should be implmented in the block below.

# %%
import random

def deal():
  card1 = draw_card()
  card2 = draw_card()
  """
  Write a function that returns a list of 2 random cards.
  Hint: you will probably find it helpful to use the list "deck" from the starter code
  """
  cards = [card1,card2]
  #print('the cards dealt are', cards)
  return cards # FIXME: Temporarily here so your code will run


def sum_of_hand(hand):
  card = 0
  total = 0
  for card in hand:
    # saying the Jack, Queen and King are 10s
    if card == 'Jack' or card == 'Queen' or card == 'King':
      card = 10
    # saying the Ace is a 1
    elif card  == 'Ace':
      card = 1
    # adds the new card to the running total to get a new total
    total = int(total) + int(card)
  """
  This function takes in a list and returns the sum of its content.
  Watch out for face cards versus regular numbers.
  """
  return total # FIXME: Temporarily here so your code will run


def who_won(player, dealer):
  # the if statements make it so a bust will result in them at 0
  if player > 21:
    player = 0
  if dealer > 21:
    dealer = 0
  winner = player >= dealer
  """
  The input to this function is two integers, the final total of the player and dealer's hands.
  A total of 0 for either player would indicate they busted.
  If both busted, the dealer wins. If it is a tie the player wins.
  Returns true if the player won, false if the dealer won.
  """
  return winner # FIXME: Temporarily here so your code will run

# %% [markdown]
# ## Dealer and Player's turns
# Teammate #2 will implement the `players_turn` and `dealers_turn` functions.
#
# ### `players_turn`
# * This function takes in the player's hand as input.
# * The player will continuously be asked to "hit" or "stay" until they select "stay".
# * Each time they are prompted, print out their hand for them so they can see their cards.
# * If they select "hit", you will add a random card to their hand.
# * If they decide to hit and go over 21, they busted and the dealer has won the round
# * If the player busts, return 0, otherwise return the sum of their final hand.
#
# ### `dealers_turn`
# * This function takes in the dealer's hand as input.
# * Have the dealer continue adding cards to their hand until their total is greater than or equal to 17.
#   * They may already be greater than or equal to 17 from their two original cards.
# * Print out the dealer's hand each time they add a card.
# * If the dealer busts, return 0, otherwise return the sum of their final hand.
#
#
# NOTE: you will use your teammate's `sum_of_hand` code in this function, however you can get started with the placeholder code above.
#
# Implement your code in the block below.

# %%
# This function is the entirety of the player's turn. This function takes
# in the player's hand as input.If the player busts, return 0,
# otherwise return the sum of their final hand. See step 5.
def players_turn(p_hand,d_hand):
  print()
  print("Your turn")
  print('Your cards are', p_hand)
  print("The Dealer's face up card is a", d_hand[0])
  print('your total is', sum_of_hand(p_hand))
  while sum_of_hand(p_hand) < 21:
    #print('your total is', sum_of_hand(p_hand))
    choice = input("Hit or Stay? Press h or s: ")
    if choice == "h":
      drawn_card = draw_card()
      p_hand.append(drawn_card)
      print('you got a', drawn_card)
      print('your hand consists of', p_hand)
      print('your total is', sum_of_hand(p_hand))
      if sum_of_hand(p_hand) > 21:
        p_hand = []
        print('you busted')
        return 0
    elif choice == "s":
      return sum_of_hand(p_hand)
    else:
      print("invalid choice")
      choice = input("Hit or Stay? Press h or s: ")

  """
  This function is the entirety of the player's turn. This function takes
  in the player's hand as input.If the player busts, return 0,
  otherwise return the sum of their final hand.
  """
  return sum_of_hand(p_hand) # FIXME: Temporarily here so your code will run


def dealers_turn(d_hand):
  print()
  print("Dealer's turn")
  print("the dealer's cards are", d_hand)
  print("the dealer has a total of", sum_of_hand(d_hand))
  while sum_of_hand(d_hand) < 17:
    drawn_card = draw_card()
    d_hand.append(drawn_card)
    print('the dealer drew a', drawn_card)
    print("the dealer's total is", sum_of_hand(d_hand))
    if sum_of_hand(d_hand) > 21:
      print('the dealer BUSTED')
      d_hand = []
      return 0




  """ This function is the entirety of the dealer's turn. This function takes
  in the dealer's hand as input. If the dealer busts, return 0,
  otherwise return the sum of their final hand.
  Remember, this will not be exactly the same as the player's turn! See step 6."""
  return sum_of_hand(d_hand) # FIXME: Temporarily here so your code will run

# %% [markdown]
# ### Driver code
# Teammate #3 will implement the driver code, which utilizes the functions defined by your teammates to execute the game. Your code should do the following:
#
# #### Starting the game
# * Initialize the player `money` to 10.00
#
# #### Rounds
# * At the beginning of each round, ask the user if they would like to "play" or "quit"
#   * If they choose to quit, the game ends - when the game ends, print the final `money` of the player.
#   * If they play, make sure they have more than 0 dollars. If they don't, end the game. If they do, ask them how much they would like to bet
#     * Ensure that the bet is within their budget; ask them to input a bet until they give one they can afford.
# * Use the `deal` function to create the initial hands for your player and dealer.
# * First, it's the player's turn. Use the `players_turn` function, which will return the player's score after their turn.
# * Next, it's the dealer's turn. Use the `dealers_turn` function, which will return the dealer's score
# * Use the `who_won` function to determine who won. After doing so, you should
#   * Print the results
#   * Update the player's `money`, depending on if they won or lost
#   * Print the current `money` that the player has.
# * Start a new round!
#
# The logic for this code can be implemented immediately, but until your teammates have all completed their parts, it will not be fully functional. Implement the code in the block below (no functions necessary).

# %%
money = 10.00 #sets money to 10 dollars at the beginning, before any rounds are played

playQuit = input("Would you like to play, or quit? Enter P to play or any other letter to quit: ")
#gives player option to play or not.
while playQuit == "P" or playQuit == "p":
  reset_deck()
  print()
  while money > 0:
    print('you have $', money)
    betMoney = float(input("How much money will you bet? "))
    #If money is greater than 0, player gets to play
    while betMoney >= money:
      print("Sorry, you'll have to enter another value")
      betMoney = float(input("How much money will you bet? "))
      #If player enters an invalid amount, they get an infinite number of chances to get it right
      print("You bet", betMoney, "dollars!")
      #Tells player how much they bet

    #fetches the deal, players_turn, and dealers_turn function in order to determine who has what cards, and who won
    player_get = deal()
    dealer_get = deal()
    players_score = players_turn(player_get, dealer_get)
    dealers_score = dealers_turn(dealer_get)
    victor = who_won(players_score, dealers_score)



#If player wins, it shows and calculates how much money they won
    if victor == True:
      print ("You won $", betMoney, "!")
      money = money + betMoney
#If player loses, it shows and calculates how much money they lost
    if victor == False:
      print ("You lost $", betMoney, "!")
      money = money - betMoney

  #if a player is out of money, the program quits
  print ("Sorry, you're out of money.")
  quit()
#displays who much money a player has
print ("Thanks for playing! You have $",money,".")
# Out:
# Would you like to play, or quit? Enter P to play or any other letter to quit: P
#
# you have $ 10.0
# How much money will you bet? 5
#
# Your turn
# Your cards are ['2', '7']
# The Dealer's face up card is a Ace
# your total is 9
# Hit or Stay? Press h or s: h
# you got a 9
# your hand consists of ['2', '7', '9']
# your total is 18
# Hit or Stay? Press h or s: s
#
# Dealer's turn
# the dealer's cards are ['Ace', 'Jack']
# the dealer has a total of 11
# the dealer drew a 6
# the dealer's total is 17
# You won $ 5.0 !
# you have $ 15.0
# How much money will you bet? 5
#
# Your turn
# Your cards are ['Ace', 'Queen']
# The Dealer's face up card is a King
# your total is 11
# Hit or Stay? Press h or s: h
# you got a Ace
# your hand consists of ['Ace', 'Queen', 'Ace']
# your total is 12
# Hit or Stay? Press h or s: h
# you got a King
# your hand consists of ['Ace', 'Queen', 'Ace', 'King']
# your total is 22
# you busted
#
# Dealer's turn
# the dealer's cards are ['King', '6']
# ...

# %% [markdown]
# #README:
# Play all cells before number 3, otherwise the code won't work.
